# %%
# Function IPYNB import
import import_ipynb
from function import dtConv, locate

# Library Imports
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from statistics import mean, median, mode, stdev
import plotly as py
import plotly.graph_objects as go

# %matplotlib inline
# Out:
# importing Jupyter notebook from function.ipynb

# %%
df = pd.read_csv("../DATA/newTest.csv", sep=",", header=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 48 columns):
# CutitronicsTreatmentID    408 non-null int64
# TreatmentNumber           408 non-null int64
# CutitronicsCartID         408 non-null object
# CutitronicsSKUID          408 non-null object
# CartLevel                 408 non-null float64
# CartState                 408 non-null object
# CartDispensedAmount       408 non-null int64
# CartEnvTemperature        408 non-null int64
# CartEnvHumidity           408 non-null int64
# CartEnvPollution          408 non-null int64
# CartEnvUv                 408 non-null int64
# CutitronicsClientID       408 non-null object
# TreatmentStartDate        408 non-null object
# TreatmentType             408 non-null object
# CutitronicsCtrlID         408 non-null object
# CtrlBatteryLevel          408 non-null int64
# CtrlTemperature           408 non-null int64
# CtrlDatetime              408 non-null object
# CtrlState                 408 non-null object
# CtrlStatus                408 non-null object
# CtrlFirmwareVersion       408 non-null object
# CtrlLatitude              408 non-null float64
# CtrlLongitude             408 non-null float64
# CtrlSkinHealth            390 non-null float64
# CtrlHumidity              391 non-null float64
# CtrlaccData               401 non-null float64
# MeasurementArea           408 non-null object
# Status                    408 non-null object
# clientLat                 408 non-null float64
# clientLon                 408 non-null float64
# FirstName                 408 non-null object
# Surname                   408 non-null object
# YOB                       408 non-null int64
# Gender                    408 non-null object
# FITZP                     408 non-null int64
# SkinConcerns              408 non-null object
# Allergies                 408 non-null object
# CutitronicsBrandID        408 non-null object
# CutitronicsSKUCat         408 non-null object
# CutitronicsSKUType        408 non-null object
# CutitronicsSKUName        408 non-null object
# prescribedOn              408 non-null object
# PrescriptionName          393 non-null object
# PrescriptionType          408 non-null object
# presrcibedAM              408 non-null int64
# prescribedPM              408 non-null int64
# CartInitLevel             408 non-null int64
# installDate               408 non-null object
# dtypes: float64(8), int64(14), object(26)
# memory usage: 153.1+ KB

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent*100], axis=1, keys=['Total', 'Percent'])

f, ax = plt.subplots(figsize=(15, 6))
plt.xticks(rotation='90')
sns.barplot(x=missing_data.index, y=missing_data['Percent'])
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5,1,'Percent missing data by feature')

# %%
dtConv(df)
locate(df)

# %%
# sns.set(style="ticks", palette="pastel")

# # Draw a nested boxplot
# sns.boxplot(x="PrescriptionType", y="CtrlSkinHealth",
#             hue="Area",
#             data=df)
# sns.despine(offset=10, trim=True)

# %%
# fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
# fig.write_html('first_figure.html', auto_open=True)

# %%
df.to_csv(r'../DATA/2807.csv', index = False)
